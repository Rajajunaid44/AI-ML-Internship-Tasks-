# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data1=pd.read_csv(r"C:\Users\HP\Downloads\archive (18)\Iris.csv")
data1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Column name
data1.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#shape
data1.shape
# Out:
# (150, 6)

# %%
#info
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#describe
data1.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#scatter lot between sepal length and sepal width
plt.scatter(x=data1['SepalLengthCm'],y=data1['SepalWidthCm'],c=data1['SepalLengthCm'])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.savefig('Scatter plot between sepal length and width')

# %%
#histogram
plt.hist(x=data1['SepalLengthCm'])
plt.xlabel('SepalLengthCm')
plt.savefig('Histogram 1')

# %%
plt.hist(x=data1['SepalWidthCm'])
plt.xlabel('SepalWidthCm')
plt.savefig('Histogram 2')

# %%
plt.hist(x=data1['PetalLengthCm'])
plt.xlabel('PetalLengthCm')
plt.savefig('Histogram 3')

# %%
plt.hist(x=data1['PetalWidthCm'])
plt.xlabel('PetalWidthCm')
plt.savefig('Histogram 4')

# %%
#boxplots
sns.boxplot(x=data1['SepalLengthCm'])
plt.savefig('Boxplot1')

# %%
sns.boxplot(x=data1['SepalWidthCm'])
plt.savefig('Boxplot2')

# %%
sns.boxplot(x=data1['PetalLengthCm'])
plt.savefig('Boxplot3')

# %%
sns.boxplot(x=data1['PetalWidthCm'])
plt.savefig('Boxplot4')
